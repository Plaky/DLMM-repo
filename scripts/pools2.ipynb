# %%
import requests

# API Base URL
BASE_URL = "https://dlmm-api.meteora.ag"

# Define the endpoint
endpoint = "/pair/all_by_groups"

# Query parameters
params = {
    "page": "1",
    "limit": "10",  # Get only 10 results
    "sort_key": "vol",  # Sort by Total Value Locked
    "order_by": "desc",  # Sort in descending order (highest TVL first)
    "hide_low_tvl": "10000"  # Hide pools with TVL lower than $10,000
}

# Make the API request
try:
    response = requests.get(BASE_URL + endpoint, params=params)
    response.raise_for_status()  # Raise an error if request fails
    data = response.json()  # Parse JSON response

    # Display pool groups
    for group in data["groups"]:
        print(f"Group Name: {group['name']}")
        for pool in group["pairs"]:
            print(f"  - Pool: {pool['name']}, TVL: {pool['liquidity']}, APR: {pool.get('apr', 'N/A')}")
        print("\n")

except requests.exceptions.RequestException as e:
    print(f"Error fetching data: {e}")
# Out:
# Group Name: Fartcoin -SOL
#   - Pool: Fartcoin -SOL, TVL: 2396030.804713643, APR: 0.8653387779180177
#   - Pool: Fartcoin -SOL, TVL: 1847358.7762222635, APR: 1.555503092157273
#   - Pool: Fartcoin -SOL, TVL: 1172369.5268581093, APR: 0.6928390435814117
#   - Pool: Fartcoin -SOL, TVL: 1474949.7801165148, APR: 0.07991756600014377
#   - Pool: Fartcoin -SOL, TVL: 47381.13220660726, APR: 0.3100535041008864
#   - Pool: Fartcoin -SOL, TVL: 24059.30946418203, APR: 0.49818001904997417
#   - Pool: Fartcoin -SOL, TVL: 13735.347920383274, APR: 0.5342541710029889
#   - Pool: Fartcoin -SOL, TVL: 38992.63958103617, APR: 0.23268475614675413
#   - Pool: Fartcoin -SOL, TVL: 109953.07758948018, APR: 0.07859141635662173
#
#
# Group Name: USDT-USDC
#   - Pool: USDC-USDT, TVL: 4952763.293516807, APR: 0.0005312132112356604
#   - Pool: USDT-USDC, TVL: 363337.21438808186, APR: 0.0008467203458647205
#   - Pool: USDC-USDT, TVL: 90452.01766511513, APR: 0.0016547452249851963
#   - Pool: USDC-USDT, TVL: 19235.297355423136, APR: 0.0006001842447392746
#   - Pool: USDC-USDT, TVL: 14152.150406835935, APR: 6.99396460852972e-05
#   - Pool: USDT-USDC, TVL: 84833.12071766211, APR: 0.0
#   - Pool: USDC-USDT, TVL: 210202.3592817179, APR: 0.0
#   - Pool: USDC-USDT, TVL: 36344.919977779595, APR: 0.0
#   - Pool: USDC-USDT, TVL: 15428.502234058122, APR: 0.0
#
#
# Group Name: arc-SOL
#   - Pool: arc-SOL, TVL: 497908.44659957226, APR: 16.31524095591016
#   - Pool: arc-SOL, TVL: 1155188.120973013, APR: 2.9895046622818118
#   - Pool: arc-SOL, TVL: 1300118.9911026575, APR: 2.4670723564546315
#   - Pool: arc-SOL, TVL: 1339578.9609223022, APR: 2.5620436414157135
#   - Pool: arc-SOL, TVL: 161072.39010538367, APR: 2.082899928925844
#   - Pool: arc-SOL, TVL: 30006.76452633739, APR: 2.7900283931524097
#
#
# Group Name: AskJ-arc
#   - Pool: AskJ-arc, TVL: 4252088.272500787, APR: 22.407178246402907
#   - Pool: AskJ-arc, TVL: 60268.09280004949, APR: 0.2456995487270837
#
#
# Group Name: CLOUD-USDC
#   - Pool: USDC-CLOUD, TVL: 3549329.423906267, APR: 0.021134410299320536
#   - Pool: CLOUD-USDC, TVL: 12976.870869119308, APR: 0.0
#
#
# Group Name: JUP-USDC
#   - Pool: JUP-USDC, TVL: 615789.3240064778, APR: 0.37255847361318456
#   - Pool: JUP-USDC, TVL: 281454.4815400095, APR: 0.6866385461693627
#   - Pool: JUP-USDC, TVL: 161700.38660228674, APR: 0.15038902451008582
#   - Pool: JUP-USDC, TVL: 254994.79389061112, APR: 0.20371907104390247
#   - Pool: JUP-USDC, TVL: 108270.27376455617, APR: 0.16581017903910053
#   - Pool: JUP-USDC, TVL: 27483.99575299556, APR: 1.2799178551480983
#   - Pool: JUP-USDC, TVL: 1382534.056768296, APR: 0.014019823315487156
#   - Pool: JUP-USDC, TVL: 82213.67112461201, APR: 0.12657793008174417
#   - Pool: JUP-USDC, TVL: 133544.18548772513, APR: 0.2503335388598932
#   - Pool: JUP-USDC, TVL: 166847.84977342686, APR: 0.1685532032628573
#   - Pool: JUP-USDC, TVL: 44659.97503766238, APR: 0.037241629039304024
#   - Pool: JUP-USDC, TVL: 14286.650798721688, APR: 0.002064183533342965
#   - Pool: JUP-USDC, TVL: 19545.08645982858, APR: 0.010251687587196138
#
#
# Group Name: sSOL-SOL
#   - Pool: sSOL-SOL, TVL: 2729005.6718484964, APR: 0.0021025315799095804
#   - Pool: sSOL-SOL, TVL: 84720.250566148, APR: 0.0009107304079825111
#
#
# Group Name: WBTC-USDC
#   - Pool: WBTC-USDC, TVL: 1392301.9942747536, APR: 0.19242197310143005
#   - Pool: WBTC-USDC, TVL: 747203.2307564802, APR: 0.08282733504462943
#   - Pool: WBTC-USDC, TVL: 91102.77142146592, APR: 0.032420872894971156
#   - Pool: WBTC-USDC, TVL: 92353.61603623336, APR: 0.10456243755133507
#   - Pool: WBTC-USDC, TVL: 15187.037059343575, APR: 0.03830345332652605
#
#
# Group Name: PENGU-USDC
#   - Pool: PENGU-USDC, TVL: 482269.5799371975, APR: 0.36595192807781696
#   - Pool: PENGU-USDC, TVL: 583548.4751723526, APR: 0.2579012993048969
#   - Pool: PENGU-USDC, TVL: 392807.2801296513, APR: 0.020462161367887956
#   - Pool: PENGU-USDC, TVL: 96072.20695021356, APR: 0.00773191997585297
#   - Pool: PENGU-USDC, TVL: 120574.2291215932, APR: 0.007558731236520301
#   - Pool: PENGU-USDC, TVL: 321442.0953985805, APR: 5.777148854182397e-07
#
#
# Group Name: RYAN-USDC
#   - Pool: RYAN-USDC, TVL: 1864068.2598967166, APR: 0.0
